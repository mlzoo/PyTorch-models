# %%
plain_train_18_acc = []
plain_train_18_loss = []
plain_train_18_val_acc = []
plain_train_18_val_loss = []

plain_train_34_acc = []
plain_train_34_loss = []
plain_train_34_val_acc = []
plain_train_34_val_loss = []

filename = 'plainet-18-2022-01-10 01:54:17.822771+08:00-train-acc.txt'
with open(filename, 'r') as f:
    while True:
        lines = f.readline() # 整行读取数据
        if not lines:
            break
        
        
        plain_train_18_acc.append(float(lines))
        
filename = 'plainet-18-2022-01-10 01:54:17.822771+08:00-train-loss.txt'
with open(filename, 'r') as f:
    while True:
        lines = f.readline() # 整行读取数据
        if not lines:
            break
        
        plain_train_18_loss.append(float(lines))
        
filename = 'plainet-18-2022-01-10 01:54:17.822771+08:00-val-acc.txt'
with open(filename, 'r') as f:
    while True:
        lines = f.readline() # 整行读取数据
        if not lines:
            break
        
        plain_train_18_val_acc.append(float(lines))
        
filename = 'plainet-18-2022-01-10 01:54:17.822771+08:00-val-loss.txt'
with open(filename, 'r') as f:
    while True:
        lines = f.readline() # 整行读取数据
        if not lines:
            break
        
        plain_train_18_val_loss.append(float(lines))
        

filename = 'plainet-34-2022-01-10 02:27:11.116582+08:00-train-acc.txt'
with open(filename, 'r') as f:
    while True:
        lines = f.readline() # 整行读取数据
        if not lines:
            break
        
        
        plain_train_34_acc.append(float(lines))
        
filename = 'plainet-34-2022-01-10 02:27:11.116582+08:00-train-loss.txt'
with open(filename, 'r') as f:
    while True:
        lines = f.readline() # 整行读取数据
        if not lines:
            break
        
        plain_train_34_loss.append(float(lines))
        
filename = 'plainet-34-2022-01-10 02:27:11.116582+08:00-val-acc.txt'
with open(filename, 'r') as f:
    while True:
        lines = f.readline() # 整行读取数据
        if not lines:
            break
        
        
        plain_train_34_val_acc.append(float(lines))
        
filename = 'plainet-34-2022-01-10 02:27:11.116582+08:00-val-loss.txt'
with open(filename, 'r') as f:
    while True:
        lines = f.readline() # 整行读取数据
        if not lines:
            break
        
        
        plain_train_34_val_loss.append(float(lines))

# %%
resnet_train_18_acc = []
resnet_train_18_loss = []
resnet_train_18_val_acc = []
resnet_train_18_val_loss = []

resnet_train_34_acc = []
resnet_train_34_loss = []
resnet_train_34_val_acc = []
resnet_train_34_val_loss = []

filename = 'resnet-18-2022-01-10 14:40:01.863133+08:00-train-acc.txt'
with open(filename, 'r') as f:
    while True:
        lines = f.readline() # 整行读取数据
        if not lines:
            break
        
        
        resnet_train_18_acc.append(float(lines))
        
filename = 'resnet-18-2022-01-10 14:40:01.863133+08:00-train-loss.txt'
with open(filename, 'r') as f:
    while True:
        lines = f.readline() # 整行读取数据
        if not lines:
            break
        
        resnet_train_18_loss.append(float(lines))
        
filename = 'resnet-18-2022-01-10 14:40:01.863133+08:00-val-acc.txt'
with open(filename, 'r') as f:
    while True:
        lines = f.readline() # 整行读取数据
        if not lines:
            break
        
        resnet_train_18_val_acc.append(float(lines))
        
filename = 'resnet-18-2022-01-10 14:40:01.863133+08:00-val-loss.txt'
with open(filename, 'r') as f:
    while True:
        lines = f.readline() # 整行读取数据
        if not lines:
            break
        
        resnet_train_18_val_loss.append(float(lines))
        

filename = 'resnet-34-2022-01-10 15:15:16.038145+08:00-train-acc.txt'
with open(filename, 'r') as f:
    while True:
        lines = f.readline() # 整行读取数据
        if not lines:
            break
        
        
        resnet_train_34_acc.append(float(lines))
        
filename = 'resnet-34-2022-01-10 15:15:16.038145+08:00-train-loss.txt'
with open(filename, 'r') as f:
    while True:
        lines = f.readline() # 整行读取数据
        if not lines:
            break
        
        resnet_train_34_loss.append(float(lines))
        
filename = 'resnet-34-2022-01-10 15:15:16.038145+08:00-val-acc.txt'
with open(filename, 'r') as f:
    while True:
        lines = f.readline() # 整行读取数据
        if not lines:
            break
        
        
        resnet_train_34_val_acc.append(float(lines))
        
filename = 'resnet-34-2022-01-10 15:15:16.038145+08:00-val-loss.txt'
with open(filename, 'r') as f:
    while True:
        lines = f.readline() # 整行读取数据
        if not lines:
            break
        
        resnet_train_34_val_loss.append(float(lines))

# %%
import matplotlib.pyplot as plt

plt.figure()
# plt.plot(plain_train_18_acc,'ro-',color='red', label='plainet 18 train acc')
plt.plot(plain_train_18_val_acc,'ro-',color='red', label='plainet 18 val acc')
# plt.plot(plain_train_34_acc,'ro-',color='violet', label='plainet 34 train acc')
plt.plot(plain_train_34_val_acc,'ro-',color='violet', label='plainet 34 val acc')

# plt.plot(resnet_train_18_acc,'rx-',color='red', label='resnet 18 train acc')
plt.plot(resnet_train_18_val_acc,'rx-',color='blue', label='resnet 18 val acc')
# plt.plot(resnet_train_34_acc,'rx-',color='violet', label='resnet 34 train acc')
plt.plot(resnet_train_34_val_acc,'rx-',color='green', label='resnet 34 val acc')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(plain_train_18_acc,'ro-',color='red', label='plainet 18 train acc')
# plt.plot(plain_train_18_val_acc,'ro-',color='blue', label='plainet 18 val acc')
plt.plot(plain_train_34_acc,'ro-',color='violet', label='plainet 34 train acc')
# plt.plot(plain_train_34_val_acc,'ro-',color='green', label='plainet 34 val acc')

plt.plot(resnet_train_18_acc,'rx-',color='blue', label='resnet 18 train acc')
# plt.plot(resnet_train_18_val_acc,'rx-',color='blue', label='resnet 18 val acc')
plt.plot(resnet_train_34_acc,'rx-',color='green', label='resnet 34 train acc')
# plt.plot(resnet_train_34_val_acc,'rx-',color='green', label='resnet 34 val acc')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.figure()
# plt.plot(plain_train_18_loss,'ro-',color='red', label='plainet 18 train loss')
plt.plot(plain_train_18_val_loss,'ro-',color='red', label='plainet 18 val loss')
# plt.plot(plain_train_34_loss,'ro-',color='violet', label='plainet 34 train loss')
plt.plot(plain_train_34_val_loss,'ro-',color='violet', label='plainet 34 val loss')

# plt.plot(resnet_train_18_loss,'rx-',color='red', label='resnet 18 train loss')
plt.plot(resnet_train_18_val_loss,'rx-',color='blue', label='resnet 18 val loss')
# plt.plot(resnet_train_34_loss,'rx-',color='violet', label='resnet 34 train loss')
plt.plot(resnet_train_34_val_loss,'rx-',color='green', label='resnet 34 val loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(plain_train_18_loss,'ro-',color='red', label='plainet 18 train loss')
# plt.plot(plain_train_18_val_loss,'ro-',color='blue', label='plainet 18 val loss')
plt.plot(plain_train_34_loss,'ro-',color='violet', label='plainet 34 train loss')
# plt.plot(plain_train_34_val_loss,'ro-',color='green', label='plainet 34 val loss')

plt.plot(resnet_train_18_loss,'rx-',color='blue', label='resnet 18 train loss')
# plt.plot(resnet_train_18_val_loss,'rx-',color='blue', label='resnet 18 val loss')
plt.plot(resnet_train_34_loss,'rx-',color='green', label='resnet 34 train loss')
# plt.plot(resnet_train_34_val_loss,'rx-',color='green', label='resnet 34 val loss')
plt.legend()
